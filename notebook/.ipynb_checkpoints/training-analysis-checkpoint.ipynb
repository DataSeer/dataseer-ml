# %%
import numpy as np
import pandas as pd
import matplotlib
import string
import nltk

#read the training data
df = pd.read_csv('../resources/dataset/dataseer/corpus/DataSeer-NLP_Deliverable_500_Combined-xlsx.csv', encoding = "UTF-8")

df.sample(4)
# Out:
#        Journal  Article #                          Manuscript ID or DOI  \
# 1314  PLOS ONE        317  https://doi.org/10.1371/journal.pone.0207442
# 2800  PLOS ONE        443  https://doi.org/10.1371/journal.pone.0209854
# 153   PLOS ONE         27  https://doi.org/10.1371/journal.pone.0204016
# 3071  PLOS ONE        401  https://doi.org/10.1371/journal.pone.0209432
#
#               Data type  dataset number        Data subtype  \
# 1314            Generic             2.0                 NaN
# 2800            Generic             1.0  Subject data table
# 153   DNA sequence data             1.0          Annotation
# 3071    Microscopy data             3.0                 NaN
#
#                  Data type: subtype                Section  \
# 1314                      Generic:    Material and methods
# 2800    Generic: Subject data table                Methods
# 153   DNA sequence data: Annotation  Materials and methods
# 3071              Microscopy data:   Materials and methods
#
#                                  Subsection title  Page number  Column number  \
# 1314                             Compliance rates          4.0            1.0
# 2800                             Study procedures          3.0            1.0
# 153                                   Annotations          3.0            1.0
# 3071  Detection of R. irregularis in root samples          4.0            1.0
#
#                                          Data paragraph  \
# 1314  For both the screening and noscreening\nprogra...
# 2800  Baseline demographic and clinical characterist...
# 153   Annotations of gene identifiers to GO terms ar...
# 3071  When the vertical hair intersected a root, AMF...
#
#                                      Data Keyword Data action word  \
# 1314                compliance rates of treatment         obtained
# 2800                     non-trial participants\n  were extracted
# 153   Annotations of gene identifiers to GO terms   are retrieved
# 3071                                AMF structure     was recorded
#
#      Specialist equipment Confidence (0-10) Notes
# 1314                  NaN               NaN   NaN
# 2800                  NaN               NaN   NaN
# 153                   NaN               NaN   NaN
# 3071           Microscope               NaN   NaN

# %%
# check and remove rows with empty text
nb1 = df.shape[0]
df['Data paragraph'].replace('', np.nan, inplace=True)

# %%
nb1 = df.shape[0]
df.dropna(subset=['Data paragraph'], inplace=True)
nb2 = df.shape[0]
print(nb1-nb2,"rows with empty paragraph text have been removed")
# df.reset_index(drop=True,inplace=True)
# Out:
# 35 rows with empty paragraph text have been removed

# %%
# cleaning data types
df = df.astype({"Data type": str})
df = df.astype({"Data subtype": str})
df = df.astype({"Data type: subtype": str})
df = df.astype({"Data Keyword": str})
df = df.astype({"Data action word": str})

def clean_fields(row):
    row["Data type"] = row["Data type"].strip()
    row["Data subtype"] = row["Data subtype"].strip()
    row["Data type: subtype"] = row["Data type: subtype"].strip().replace(" :", ":")
    row["Data Keyword"] = row["Data Keyword"].strip()
    row["Data action word"] = row["Data action word"].strip()
    return row

df = df.apply(clean_fields, axis=1)

datatypes = df['Data type'].value_counts()
print(len(datatypes), "distinct data types")
# Out:
# 62 distinct data types

# %%
datatypes.head(10)
# Out:
# Generic                2443
# Existing dataset        158
# Spectrometry data       128
# Microscopy data         117
# DNA sequence data        93
# Image                    57
# PCR data                 32
# ELISA                    29
# Flow cytometry data      28
# ECG data                 27
# Name: Data type, dtype: int64

# %%
datatypes.describe()
# Out:
# count      62.000000
# mean       54.403226
# std       309.889798
# min         1.000000
# 25%         1.000000
# 50%         4.000000
# 75%        12.750000
# max      2443.000000
# Name: Data type, dtype: float64

# %%
# just to visualize the basic distribution

import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns

x = datatypes.head(10)
#plot
plt.figure(figsize=(16,4))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("# per data type")
plt.ylabel('# of occurrences', fontsize=12)
plt.xlabel('data types ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
plt.close()

# view long tail
x = datatypes
#plot
plt.figure(figsize=(16,4))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("# per data type")
plt.ylabel('# of occurrences', fontsize=12)
plt.xlabel('data types ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
datasubtypes = df['Data type: subtype'].value_counts()
print(len(datasubtypes), "distinct data subtypes")
# Out:
# 133 distinct data subtypes

# %%
datasubtypes.head(20)
# Out:
# Generic:                        1349
# Generic: Subject data table      712
# Generic: Sample table            167
# Generic: Assay                   137
# Existing dataset:                124
# Spectrometry data:               122
# Microscopy data:                  84
# DNA sequence data:                43
# Existing dataset: Review          34
# nan                               31
# ELISA:                            29
# Flow cytometry data:              28
# PCR data:                         28
# ECG data:                         27
# DNA sequence data: Alignment      24
# Microscopy data: Image            20
# CT scan data:                     20
# Video:                            18
# MRI data:                         17
# Image:                            17
# Name: Data type: subtype, dtype: int64

# %%
# do we have ambiguous cases Data type == Data subtype? e.g. "Microscopy data: Image" and "Image:"
subtypesOnly = df['Data subtype'].value_counts()
subtypesOnlySet = df['Data subtype'].unique()
datatypesSet = df['Data type'].unique()
for datatype in datatypesSet:
    if datatype in subtypesOnlySet:
        print(datatype," -> both Data type and subtype")
# Out:
# Flow cytometry data  -> both Data type and subtype
# Image  -> both Data type and subtype
# Spectrometry data  -> both Data type and subtype
# Immunofluorescence data  -> both Data type and subtype
# Microarray data  -> both Data type and subtype
# Morphology  -> both Data type and subtype

# %%
# just to visualize the basic distribution
x = datasubtypes.head(10)
#plot
plt.figure(figsize=(16,4))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("# per data subtypes")
plt.ylabel('# of occurrences', fontsize=12)
plt.xlabel('data subtypes ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
sections = df['Section'].value_counts()
print(len(sections), "distinct section titles")
# Out:
# 48 distinct section titles

# %%
sections.head(10)
# Out:
# Materials and methods    1839
# Methods                   677
# Material and methods      250
# Materials and Methods     183
# Method                     63
# Patients and methods       38
# Methodology                36
# Methods and materials      35
# Materials & methods        33
# Subjects and methods       26
# Name: Section, dtype: int64

# %%
# just to visualize the basic distribution
x = sections.head(10)
#plot
plt.figure(figsize=(16,4))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("# per section title")
plt.ylabel('# of occurrences', fontsize=12)
plt.xlabel('section titles ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
print("Variations in the length of the texts")
lens = df['Data paragraph'].str.len()
print('mean:', lens.mean(), 'std:', lens.std(), 'max:', lens.max())
# Out:
# Variations in the length of the texts
# mean: 182.46575748591758 std: 102.55516597666966 max: 1602

# %%
lens.hist(bins=20)

# %%
# text duplicates
all_texts = df['Data paragraph']
all_texts = [str(x) for x in all_texts]
sentences = [''.join(c for c in s if c not in string.punctuation) for s in all_texts]
frequency = nltk.FreqDist(sentences)
frequency.plot(10, cumulative = False)

# %%
duplicates =0
for key in frequency:
    if frequency[key] > 1:
        duplicates += 1
print(duplicates,"duplicated texts")
# Out:
# 295 duplicated texts

# %%
# can we match "Data Keyword" and "Data action word" in "Data paragraph"?
nb_mismatch_data_keyword = 0
nb_mismatch_data_action_word = 0
for i in df.index:
    if df.at[i,"Data paragraph"].find(df.at[i,"Data Keyword"]) == -1:
        nb_mismatch_data_keyword += 1
    if df.at[i,"Data paragraph"].find(df.at[i,"Data action word"]) == -1:
        nb_mismatch_data_action_word += 1
print(nb_mismatch_data_keyword, "mismatched Data keywords out of", df.shape[0])
print(nb_mismatch_data_action_word, "mismatched Data action word out of", df.shape[0])
# Out:
# 247 mismatched Data keywords out of 3373
# 135 mismatched Data action word out of 3373
